# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('examples/ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table('examples/ex1.csv', sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('examples/ex1.csv', header=None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
pd.read_csv('examples/ex1.csv', header = None, names=['a','b','c','d','message'])
# Out:
#    a   b   c   d  message
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
names=['a','b','c','d','message']

# %%
pd.read_csv('examples/ex1.csv', names = names, index_col = 'message')
# Out:
#          a   b   c   d
# message
# message  a   b   c   d
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
parsed = pd.read_csv('examples/csv_mindex.csv', index_col=['key1','key2'])

# %%
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd.read_csv('examples/csv_mindex.csv')
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
list(open('examples/ex3.txt'))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %%
pd.read_table('examples/ex3.txt', sep='\s+')
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
pd.read_csv('examples/ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('examples/ex4.csv', skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
res = pd.read_csv('examples/ex5.csv')

# %%
res
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(res)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
res.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
res = pd.read_csv('examples/ex5.csv', na_values='NULL')

# %%
res
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
senti = {'message':['foo','NA'],'something':['two']}

# %%
pd.read_csv('examples/ex5.csv')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.read_csv('examples/ex5.csv', na_values=senti)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %%
pd.read_csv('examples/ex5.csv', na_values=['world'])
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8     NaN
# 2     three  9  10  11.0  12     foo

# %%
pd.read_csv('http://bit.ly/imdbratings').head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv('http://bit.ly/imdbratings',sep='\t').head()
# Out:
#   star_rating,title,content_rating,genre,duration,actors_list
# 0  9.3,The Shawshank Redemption,R,Crime,142,"[u'T...
# 1  9.2,The Godfather,R,Crime,175,"[u'Marlon Brand...
# 2  9.1,The Godfather: Part II,R,Crime,200,"[u'Al ...
# 3  9,The Dark Knight,PG-13,Action,152,"[u'Christi...
# 4  8.9,Pulp Fiction,R,Crime,154,"[u'John Travolta...

# %%
pd.read_csv('http://bit.ly/imdbratings', sep=',').head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv('http://bit.ly/imdbratings').head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv('http://bit.ly/imdbratings',header=None).head()
# Out:
#              0                         1               2       3         4  \
# 0  star_rating                     title  content_rating   genre  duration
# 1          9.3  The Shawshank Redemption               R   Crime       142
# 2          9.2             The Godfather               R   Crime       175
# 3          9.1    The Godfather: Part II               R   Crime       200
# 4            9           The Dark Knight           PG-13  Action       152
#
#                                                    5
# 0                                        actors_list
# 1  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
pd.read_csv('http://bit.ly/imdbratings', index_col = ['title']).head()
# Out:
#                           star_rating content_rating   genre  duration  \
# title
# The Shawshank Redemption          9.3              R   Crime       142
# The Godfather                     9.2              R   Crime       175
# The Godfather: Part II            9.1              R   Crime       200
# The Dark Knight                   9.0          PG-13  Action       152
# Pulp Fiction                      8.9              R   Crime       154
#
#                                                                 actors_list
# title
# The Shawshank Redemption  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# The Godfather               [u'Marlon Brando', u'Al Pacino', u'James Caan']
# The Godfather: Part II    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# The Dark Knight           [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# Pulp Fiction              [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv('http://bit.ly/imdbratings').columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
r.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
names = ['rating','title','content_rating','genre','duration','actors']

# %%
names
# Out:
# ['rating', 'title', 'content_rating', 'genre', 'duration', 'actors']

# %%
pd.read_csv('http://bit.ly/imdbratings', header = None, names = names).head()
# Out:
#         rating                     title  content_rating   genre  duration  \
# 0  star_rating                     title  content_rating   genre  duration
# 1          9.3  The Shawshank Redemption               R   Crime       142
# 2          9.2             The Godfather               R   Crime       175
# 3          9.1    The Godfather: Part II               R   Crime       200
# 4            9           The Dark Knight           PG-13  Action       152
#
#                                               actors
# 0                                        actors_list
# 1  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
pd.read_csv('http://bit.ly/imdbratings', names = names).head()
# Out:
#         rating                     title  content_rating   genre  duration  \
# 0  star_rating                     title  content_rating   genre  duration
# 1          9.3  The Shawshank Redemption               R   Crime       142
# 2          9.2             The Godfather               R   Crime       175
# 3          9.1    The Godfather: Part II               R   Crime       200
# 4            9           The Dark Knight           PG-13  Action       152
#
#                                               actors
# 0                                        actors_list
# 1  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 2    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 3  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
pd.read_csv('http://bit.ly/imdbratings', skiprows=1, names = names, header= None).head()
# Out:
#    rating                     title content_rating   genre  duration  \
# 0     9.3  The Shawshank Redemption              R   Crime       142
# 1     9.2             The Godfather              R   Crime       175
# 2     9.1    The Godfather: Part II              R   Crime       200
# 3     9.0           The Dark Knight          PG-13  Action       152
# 4     8.9              Pulp Fiction              R   Crime       154
#
#                                               actors
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.read_csv('http://bit.ly/imdbratings', na_values='Tariq')
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
daf = pd.read_csv('http://bit.ly/imdbratings', na_values='Tari')

# %%
df = daf.isnull()

# %%
df
# Out:
#      star_rating  title  content_rating  genre  duration  actors_list
# 0          False  False           False  False     False        False
# 1          False  False           False  False     False        False
# 2          False  False           False  False     False        False
# 3          False  False           False  False     False        False
# 4          False  False           False  False     False        False
# ..           ...    ...             ...    ...       ...          ...
# 974        False  False           False  False     False        False
# 975        False  False           False  False     False        False
# 976        False  False           False  False     False        False
# 977        False  False           False  False     False        False
# 978        False  False           False  False     False        False
#
# [979 rows x 6 columns]

# %%
daf[df]
# Out:
#      star_rating title content_rating genre  duration actors_list
# 0            NaN   NaN            NaN   NaN       NaN         NaN
# 1            NaN   NaN            NaN   NaN       NaN         NaN
# 2            NaN   NaN            NaN   NaN       NaN         NaN
# 3            NaN   NaN            NaN   NaN       NaN         NaN
# 4            NaN   NaN            NaN   NaN       NaN         NaN
# ..           ...   ...            ...   ...       ...         ...
# 974          NaN   NaN            NaN   NaN       NaN         NaN
# 975          NaN   NaN            NaN   NaN       NaN         NaN
# 976          NaN   NaN            NaN   NaN       NaN         NaN
# 977          NaN   NaN            NaN   NaN       NaN         NaN
# 978          NaN   NaN            NaN   NaN       NaN         NaN
#
# [979 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-0ac921c19f1a> in <module>
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
pd.read_csv('examples/ex5.csv', na_values=['world','foo','two'])
# Out:
#   something  a   b     c   d  message
# 0       one  1   2   3.0   4      NaN
# 1       NaN  5   6   NaN   8      NaN
# 2     three  9  10  11.0  12      NaN

# %%
pd.options.display.max_rows = 30

# %%
pd.read_csv('examples/ex6.csv')
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv('examples/ex6.csv', nrows= 5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=100)

# %%
chunker

# %%
for i in chunker:
    print(i)
# Out:
#          one       two     three      four key
# 0   0.467976 -0.038649 -0.295344 -1.824726   L
# 1  -0.358893  1.404453  0.704965 -0.200638   B
# 2  -0.501840  0.659254 -0.421691 -0.057688   G
# 3   0.204886  1.074134  1.388361 -0.982404   R
# 4   0.354628 -0.133116  0.283763 -0.837063   Q
# ..       ...       ...       ...       ...  ..
# 95  1.106521  0.098153  0.789793  1.192693   T
# 96 -0.540543  1.782569  0.051931  0.463868   Q
# 97 -0.101980  0.981720  1.106990 -1.752269   M
# 98  0.632107 -0.761419  1.427930 -0.046928   F
# 99  1.009779 -0.608379 -1.405105 -1.175054   F
#
# [100 rows x 5 columns]
#           one       two     three      four key
# 100 -0.602748 -0.182504 -0.768164  1.260686   X
# 101 -0.039105 -0.069510 -1.358052 -0.292859   0
# 102 -0.345101 -0.179477 -0.904658 -0.071287   T
# 103 -0.759495  0.225916  2.235872 -0.004490   X
# 104 -1.686771  0.742276  0.485876  1.798507   Q
# ..        ...       ...       ...       ...  ..
# ...

# %% [markdown]
# # Writing Data to Text Format

# %%
data = pd.read_csv('examples/ex5.csv')

# %%
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv('examples/out.csv')

# %%
pd.read_csv('examples/out.csv')
# Out:
#    Unnamed: 0 something  a   b     c   d message
# 0           0       one  1   2   3.0   4     NaN
# 1           1       two  5   6   NaN   8   world
# 2           2     three  9  10  11.0  12     foo

# %%
import sys

# %%
data.to_csv('sys.stdout', sep='|')

# %%
data.to_csv('second.csv', index = False)

# %%
pd.read_csv('second.csv')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
data.to_csv('third.csv', header = None, index=False)

# %%
pd.read_csv('third.csv', header=None)
# Out:
#        0  1   2     3   4      5
# 0    one  1   2   3.0   4    NaN
# 1    two  5   6   NaN   8  world
# 2  three  9  10  11.0  12    foo

# %%
data.to_csv('third.csv', columns = ['a','c','d'], index = False)

# %%
pd.read_csv('third.csv')
# Out:
#    a     c   d
# 0  1   3.0   4
# 1  5   NaN   8
# 2  9  11.0  12

# %%
dates = pd.date_range('22/07/2020', periods= 7)

# %%
dates
# Out:
# DatetimeIndex(['2020-07-22', '2020-07-23', '2020-07-24', '2020-07-25',
#                '2020-07-26', '2020-07-27', '2020-07-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.arange(7), index = dates)

# %%
ts
# Out:
# 2020-07-22    0
# 2020-07-23    1
# 2020-07-24    2
# 2020-07-25    3
# 2020-07-26    4
# 2020-07-27    5
# 2020-07-28    6
# Freq: D, dtype: int32

# %% [markdown]
# # Working with Delimited Formats
